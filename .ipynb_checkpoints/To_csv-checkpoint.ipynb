# %%
import pandas as pd
import json

# %%
def load_game():
    with open("test_game.json") as f:
        game = json.load(f)
    with open("test_settings.json") as f:
        settings = json.load(f)
    return game, settings
    
game, settings = load_game()
game
# Out:
# {'60': {'players': [{'pre': {'frame': 60,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 3521263770,
#      'actionStateId': 65,
#      'positionX': -76.65876007080078,
#      'positionY': 20.930095672607422,
#      'facingDirection': -1,
#      'joystickX': 0,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 256,
#      'physicalButtons': 256,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 0},
#     'post': {'frame': 60,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 65,
#      'positionX': -77.83876037597656,
#      'positionY': 18.630096435546875,
#      'facingDirection': -1,
#      'percent': 0,
#      'shieldSize': 60,
#      'lastAttackLanded': 0,
#      'currentComboCount': 0,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 15,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 60,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 3521263770,
#      'actionStateId': 179,
#      'positionX': -79.95650482177734,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': 0,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 1,
#      'buttons': 2147483680,
#      'physicalButtons': 32,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 1,
#      'percent': 0},
#     'post': {'frame': 60,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 179,
#      'positionX': -79.95650482177734,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'percent': 0,
#      'shieldSize': 55.31001281738281,
#      'lastAttackLanded': 0,
#      'currentComboCount': 0,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': -1,
#      'lCancelStatus': 0}}],
#   'frame': 60},
#  '120': {'players': [{'pre': {'frame': 120,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 1307054375,
#      'actionStateId': 67,
#      'positionX': -72.1968765258789,
#      'positionY': 8.580099105834961,
#      'facingDirection': -1,
#      'joystickX': -0.987500011920929,
#      'joystickY': 0,
#      'cStickX': 0.987500011920929,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 8650752,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 0},
#     'post': {'frame': 120,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 67,
#      'positionX': -72.1968765258789,
#      'positionY': 8.580099105834961,
#      'facingDirection': -1,
#      'percent': 0,
#      'shieldSize': 60,
#      'lastAttackLanded': 15,
#      'currentComboCount': 1,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 4,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 120,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 1307054375,
#      'actionStateId': 76,
#      'positionX': -76.5245132446289,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': 0,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 1,
#      'buttons': 2147483680,
#      'physicalButtons': 32,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 1,
#      'percent': 9},
#     'post': {'frame': 120,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 76,
#      'positionX': -76.5245132446289,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'percent': 9,
#      'shieldSize': 35.29005813598633,
#      'lastAttackLanded': 0,
#      'currentComboCount': 0,
#      'lastHitBy': 0,
#      'stocksRemaining': 4,
#      'actionStateCounter': 1,
#      'lCancelStatus': 0}}],
#   'frame': 120},
#  '180': {'players': [{'pre': {'frame': 180,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 1162000790,
#      'actionStateId': 14,
#      'positionX': -85.65088653564453,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': -1,
#      'joystickX': 0,
#      'joystickY': -0.987500011920929,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 131072,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 0},
#     'post': {'frame': 180,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 39,
#      'positionX': -85.65088653564453,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': -1,
#      'percent': 0,
#      'shieldSize': 60,
#      'lastAttackLanded': 17,
#      'currentComboCount': 4,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 1,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 180,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 1162000790,
#      'actionStateId': 251,
#      'positionX': -101.44803619384766,
#      'positionY': -4.223900318145752,
#      'facingDirection': 1,
#      'joystickX': -0.38749998807907104,
#      'joystickY': -0.9125000238418579,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 131072,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 19.189998626708984},
#     'post': {'frame': 180,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 251,
#      'positionX': -102.34365844726562,
#      'positionY': -4.991900444030762,
#      'facingDirection': 1,
#      'percent': 19.189998626708984,
#      'shieldSize': 34.03004837036133,
#      'lastAttackLanded': 0,
#      'currentComboCount': 0,
#      'lastHitBy': 0,
#      'stocksRemaining': 4,
#      'actionStateCounter': 12,
#      'lCancelStatus': 0}}],
#   'frame': 180},
#  '240': {'players': [{'pre': {'frame': 240,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 1696824152,
#      'actionStateId': 20,
#      'positionX': -43.70036315917969,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': 0,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 0,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 0},
#     'post': {'frame': 240,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 20,
#      'positionX': -41.92786407470703,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'percent': 0,
#      'shieldSize': 60,
#      'lastAttackLanded': 17,
#      'currentComboCount': 4,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 11,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 240,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 1696824152,
#      'actionStateId': 66,
#      'positionX': -124.07090759277344,
#      'positionY': -15.509903907775879,
#      'facingDirection': 1,
#      'joystickX': 0,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 0,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0.0071428571827709675,
#      'percent': 19.189998626708984},
#     'post': {'frame': 240,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 66,
#      'positionX': -124.24552917480469,
#      'positionY': -16.419904708862305,
#      'facingDirection': 1,
#      'percent': 19.189998626708984,
#      'shieldSize': 38.23003005981445,
#      'lastAttackLanded': 0,
#      'currentComboCount': 0,
#      'lastHitBy': 0,
#      'stocksRemaining': 4,
#      'actionStateCounter': 28,
#      'lCancelStatus': 0}}],
#   'frame': 240},
#  '300': {'players': [{'pre': {'frame': 300,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 1507738538,
#      'actionStateId': 42,
#      'positionX': -78.17239379882812,
#      'positionY': 0.00010013580322265625,
#      'facingDirection': -1,
#      'joystickX': 0.9375,
#      'joystickY': 0.3375000059604645,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 524288,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 12},
#     'post': {'frame': 300,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 42,
#      'positionX': -77.7171630859375,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': -1,
#      'percent': 12,
#      'shieldSize': 60,
#      'lastAttackLanded': 17,
#      'currentComboCount': 4,
#      'lastHitBy': 3,
#      'stocksRemaining': 4,
#      'actionStateCounter': 1,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 300,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 1507738538,
#      'actionStateId': 66,
#      'positionX': -83.9755630493164,
#      'positionY': 11.082088470458984,
#      'facingDirection': 1,
#      'joystickX': 1,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 524288,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0.014285714365541935,
#      'percent': 19.189998626708984},
#     'post': {'frame': 300,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 66,
#      'positionX': -82.62556457519531,
#      'positionY': 11.272088050842285,
#      'facingDirection': 1,
#      'percent': 19.189998626708984,
#      'shieldSize': 42.43001174926758,
#      'lastAttackLanded': 14,
#      'currentComboCount': 1,
#      'lastHitBy': 0,
#      'stocksRemaining': 4,
#      'actionStateCounter': 18,
#      'lCancelStatus': 0}}],
#   'frame': 300},
#  '360': {'players': [{'pre': {'frame': 360,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 1442604297,
#      'actionStateId': 73,
#      'positionX': -68.670654296875,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': 0,
#      'joystickY': -0.987500011920929,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 131584,
#      'physicalButtons': 512,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 12},
#     'post': {'frame': 360,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 73,
#      'positionX': -68.670654296875,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'percent': 12,
#      'shieldSize': 60,
#      'lastAttackLanded': 17,
#      'currentComboCount': 4,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 26.755556106567383,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 360,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 1442604297,
#      'actionStateId': 234,
#      'positionX': -60.191558837890625,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': -0.800000011920929,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 1,
#      'buttons': 2147745824,
#      'physicalButtons': 32,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 1,
#      'percent': 19.189998626708984},
#     'post': {'frame': 360,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 234,
#      'positionX': -60.37791442871094,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'percent': 19.189998626708984,
#      'shieldSize': 29.900028228759766,
#      'lastAttackLanded': 14,
#      'currentComboCount': 1,
#      'lastHitBy': 0,
#      'stocksRemaining': 4,
#      'actionStateCounter': 5,
#      'lCancelStatus': 0}}],
#   'frame': 360},
#  '420': {'players': [{'pre': {'frame': 420,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 1624216561,
#      'actionStateId': 26,
#      'positionX': -32.14593505859375,
#      'positionY': 5.610099792480469,
#      'facingDirection': 1,
#      'joystickX': 0,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 0,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 12},
#     'post': {'frame': 420,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 26,
#      'positionX': -31.758609771728516,
#      'positionY': 7.020099639892578,
#      'facingDirection': 1,
#      'percent': 12,
#      'shieldSize': 60,
#      'lastAttackLanded': 17,
#      'currentComboCount': 4,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 3,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 420,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 1624216561,
#      'actionStateId': 67,
#      'positionX': -83.06558990478516,
#      'positionY': 19.902097702026367,
#      'facingDirection': -1,
#      'joystickX': -0.987500011920929,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 262144,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0.014285714365541935,
#      'physicalRTrigger': 0,
#      'percent': 19.189998626708984},
#     'post': {'frame': 420,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 67,
#      'positionX': -84.39871215820312,
#      'positionY': 20.016098022460938,
#      'facingDirection': -1,
#      'percent': 19.189998626708984,
#      'shieldSize': 34.10000991821289,
#      'lastAttackLanded': 14,
#      'currentComboCount': 1,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 20,
#      'lCancelStatus': 0}}],
#   'frame': 420},
#  '480': {'players': [{'pre': {'frame': 480,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 3949415984,
#      'actionStateId': 179,
#      'positionX': -62.47856903076172,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': 0,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 1,
#      'buttons': 2147483712,
#      'physicalButtons': 64,
#      'physicalLTrigger': 1,
#      'physicalRTrigger': 0,
#      'percent': 12},
#     'post': {'frame': 480,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 179,
#      'positionX': -62.47856903076172,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'percent': 12,
#      'shieldSize': 56.08001708984375,
#      'lastAttackLanded': 17,
#      'currentComboCount': 4,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': -1,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 480,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 3949415984,
#      'actionStateId': 67,
#      'positionX': -57.43318176269531,
#      'positionY': 52.258087158203125,
#      'facingDirection': 1,
#      'joystickX': 1,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 524288,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0.014285714365541935,
#      'percent': 19.189998626708984},
#     'post': {'frame': 480,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 67,
#      'positionX': -56.08318328857422,
#      'positionY': 52.32008743286133,
#      'facingDirection': 1,
#      'percent': 19.189998626708984,
#      'shieldSize': 38.299991607666016,
#      'lastAttackLanded': 14,
#      'currentComboCount': 1,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 19,
#      'lCancelStatus': 0}}],
#   'frame': 480},
#  '540': {'players': [{'pre': {'frame': 540,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 3592227920,
#      'actionStateId': 25,
#      'positionX': -65.29580688476562,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': 0.987500011920929,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 524288,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 12},
#     'post': {'frame': 540,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 25,
#      'positionX': -63.59580612182617,
#      'positionY': 2.100099802017212,
#      'facingDirection': 1,
#      'percent': 12,
#      'shieldSize': 59.93000030517578,
#      'lastAttackLanded': 17,
#      'currentComboCount': 4,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 0,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 540,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 3592227920,
#      'actionStateId': 56,
#      'positionX': -43.348445892333984,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': 0,
#      'joystickY': 0.6875,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 65792,
#      'physicalButtons': 256,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 19.189998626708984},
#     'post': {'frame': 540,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 56,
#      'positionX': -43.348445892333984,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'percent': 19.189998626708984,
#      'shieldSize': 42.49997329711914,
#      'lastAttackLanded': 14,
#      'currentComboCount': 1,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 4,
#      'lCancelStatus': 0}}],
#   'frame': 540},
#  '600': {'players': [{'pre': {'frame': 600,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 1127216960,
#      'actionStateId': 183,
#      'positionX': -50.068092346191406,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': 0,
#      'joystickY': -0.987500011920929,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 131072,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 21},
#     'post': {'frame': 600,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 183,
#      'positionX': -50.068092346191406,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'percent': 21,
#      'shieldSize': 60,
#      'lastAttackLanded': 17,
#      'currentComboCount': 4,
#      'lastHitBy': 3,
#      'stocksRemaining': 4,
#      'actionStateCounter': 21,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 600,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 1127216960,
#      'actionStateId': 39,
#      'positionX': -21.611190795898438,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': 0,
#      'joystickY': -0.987500011920929,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 131072,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 19.189998626708984},
#     'post': {'frame': 600,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 39,
#      'positionX': -21.078691482543945,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'percent': 19.189998626708984,
#      'shieldSize': 46.699954986572266,
#      'lastAttackLanded': 8,
#      'currentComboCount': 1,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 2,
#      'lCancelStatus': 0}}],
#   'frame': 600},
#  '660': {'players': [{'pre': {'frame': 660,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 278721036,
#      'actionStateId': 79,
#      'positionX': -17.068098068237305,
#      'positionY': 9.989738464355469e-05,
#      'facingDirection': -1,
#      'joystickX': 0,
#      'joystickY': -0.987500011920929,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 1,
#      'buttons': 2147614784,
#      'physicalButtons': 64,
#      'physicalLTrigger': 1,
#      'physicalRTrigger': 0,
#      'percent': 30.279998779296875},
#     'post': {'frame': 660,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 79,
#      'positionX': -17.068098068237305,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': -1,
#      'percent': 30.279998779296875,
#      'shieldSize': 60,
#      'lastAttackLanded': 17,
#      'currentComboCount': 4,
#      'lastHitBy': 3,
#      'stocksRemaining': 4,
#      'actionStateCounter': 3,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 660,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 278721036,
#      'actionStateId': 69,
#      'positionX': -26.519941329956055,
#      'positionY': 4.900095462799072,
#      'facingDirection': 1,
#      'joystickX': 0,
#      'joystickY': -0.987500011920929,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 131072,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 19.189998626708984},
#     'post': {'frame': 660,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 69,
#      'positionX': -26.519941329956055,
#      'positionY': 3.300095558166504,
#      'facingDirection': 1,
#      'percent': 19.189998626708984,
#      'shieldSize': 50.89993667602539,
#      'lastAttackLanded': 17,
#      'currentComboCount': 5,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 19,
#      'lCancelStatus': 0}}],
#   'frame': 660},
#  '720': {'players': [{'pre': {'frame': 720,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 2310974273,
#      'actionStateId': 24,
#      'positionX': 22.10814666748047,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': 0.987500011920929,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 524288,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 32.099998474121094},
#     'post': {'frame': 720,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 24,
#      'positionX': 23.646896362304688,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'percent': 32.099998474121094,
#      'shieldSize': 60,
#      'lastAttackLanded': 17,
#      'currentComboCount': 4,
#      'lastHitBy': 3,
#      'stocksRemaining': 4,
#      'actionStateCounter': 2,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 720,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 2310974273,
#      'actionStateId': 25,
#      'positionX': -22.08468246459961,
#      'positionY': 6.608099460601807,
#      'facingDirection': 1,
#      'joystickX': -0.9750000238418579,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 262144,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0.02142857201397419,
#      'percent': 19.189998626708984},
#     'post': {'frame': 720,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 25,
#      'positionX': -21.980682373046875,
#      'positionY': 7.146099090576172,
#      'facingDirection': 1,
#      'percent': 19.189998626708984,
#      'shieldSize': 46.13024139404297,
#      'lastAttackLanded': 17,
#      'currentComboCount': 6,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 8,
#      'lCancelStatus': 0}}],
#   'frame': 720},
#  '780': {'players': [{'pre': {'frame': 780,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 1620076923,
#      'actionStateId': 179,
#      'positionX': 16.86604881286621,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': -1,
#      'joystickX': 0,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 1,
#      'buttons': 2147483712,
#      'physicalButtons': 64,
#      'physicalLTrigger': 1,
#      'physicalRTrigger': 0,
#      'percent': 32.099998474121094},
#     'post': {'frame': 780,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 179,
#      'positionX': 16.86604881286621,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': -1,
#      'percent': 32.099998474121094,
#      'shieldSize': 56.08001708984375,
#      'lastAttackLanded': 17,
#      'currentComboCount': 4,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': -1,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 780,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 1620076923,
#      'actionStateId': 67,
#      'positionX': -11.665509223937988,
#      'positionY': 43.41209030151367,
#      'facingDirection': -1,
#      'joystickX': -0.987500011920929,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 262144,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 19.189998626708984},
#     'post': {'frame': 780,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 67,
#      'positionX': -12.998634338378906,
#      'positionY': 43.59408950805664,
#      'facingDirection': -1,
#      'percent': 19.189998626708984,
#      'shieldSize': 50.330223083496094,
#      'lastAttackLanded': 17,
#      'currentComboCount': 6,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 20,
#      'lCancelStatus': 0}}],
#   'frame': 780},
#  '840': {'players': [{'pre': {'frame': 840,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 771183313,
#      'actionStateId': 345,
#      'positionX': 17.320655822753906,
#      'positionY': 29.90009880065918,
#      'facingDirection': -1,
#      'joystickX': 0.987500011920929,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 524288,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 32.099998474121094},
#     'post': {'frame': 840,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 345,
#      'positionX': 16.212156295776367,
#      'positionY': 30.590099334716797,
#      'facingDirection': -1,
#      'percent': 32.099998474121094,
#      'shieldSize': 59.93000030517578,
#      'lastAttackLanded': 17,
#      'currentComboCount': 4,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 5,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 840,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 771183313,
#      'actionStateId': 42,
#      'positionX': 6.139239311218262,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': -1,
#      'joystickX': 0.800000011920929,
#      'joystickY': -0.6000000238418579,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 524288,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 19.189998626708984},
#     'post': {'frame': 840,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 42,
#      'positionX': 7.158614158630371,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': -1,
#      'percent': 19.189998626708984,
#      'shieldSize': 54.53020477294922,
#      'lastAttackLanded': 17,
#      'currentComboCount': 6,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 1,
#      'lCancelStatus': 0}}],
#   'frame': 840},
#  '900': {'players': [{'pre': {'frame': 900,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 3004871376,
#      'actionStateId': 25,
#      'positionX': 27.517683029174805,
#      'positionY': 30.590099334716797,
#      'facingDirection': -1,
#      'joystickX': -0.9624999761581421,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 262144,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 41.39999771118164},
#     'post': {'frame': 900,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 25,
#      'positionX': 26.718807220458984,
#      'positionY': 31.050098419189453,
#      'facingDirection': -1,
#      'percent': 41.39999771118164,
#      'shieldSize': 60,
#      'lastAttackLanded': 17,
#      'currentComboCount': 4,
#      'lastHitBy': 3,
#      'stocksRemaining': 4,
#      'actionStateCounter': 14,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 900,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 3004871376,
#      'actionStateId': 68,
#      'positionX': 15.8651123046875,
#      'positionY': 8.64009952545166,
#      'facingDirection': -1,
#      'joystickX': 0.987500011920929,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0.987500011920929,
#      'trigger': 0,
#      'buttons': 1572864,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 19.189998626708984},
#     'post': {'frame': 900,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 68,
#      'positionX': 17.1982364654541,
#      'positionY': 9.856099128723145,
#      'facingDirection': -1,
#      'percent': 19.189998626708984,
#      'shieldSize': 58.730186462402344,
#      'lastAttackLanded': 14,
#      'currentComboCount': 1,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 6,
#      'lCancelStatus': 0}}],
#   'frame': 900},
#  '960': {'players': [{'pre': {'frame': 960,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 3533012721,
#      'actionStateId': 87,
#      'positionX': -26.610260009765625,
#      'positionY': 11.554736137390137,
#      'facingDirection': 1,
#      'joystickX': -0.9375,
#      'joystickY': -0.3375000059604645,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 264192,
#      'physicalButtons': 2048,
#      'physicalLTrigger': 0.0357142873108387,
#      'physicalRTrigger': 0,
#      'percent': 63.839996337890625},
#     'post': {'frame': 960,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 87,
#      'positionX': -28.903339385986328,
#      'positionY': 11.53382396697998,
#      'facingDirection': 1,
#      'percent': 63.839996337890625,
#      'shieldSize': 60,
#      'lastAttackLanded': 17,
#      'currentComboCount': 4,
#      'lastHitBy': 3,
#      'stocksRemaining': 4,
#      'actionStateCounter': 7,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 960,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 3533012721,
#      'actionStateId': 66,
#      'positionX': 1.4528610706329346,
#      'positionY': 27.722091674804688,
#      'facingDirection': -1,
#      'joystickX': 0,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 0,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 19.189998626708984},
#     'post': {'frame': 960,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 66,
#      'positionX': 1.4528610706329346,
#      'positionY': 28.476091384887695,
#      'facingDirection': -1,
#      'percent': 19.189998626708984,
#      'shieldSize': 60,
#      'lastAttackLanded': 14,
#      'currentComboCount': 0,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 13,
#      'lCancelStatus': 0}}],
#   'frame': 960},
#  '1020': {'players': [{'pre': {'frame': 1020,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 1781172938,
#      'actionStateId': 182,
#      'positionX': -80.57640838623047,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': 0.987500011920929,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 1,
#      'buttons': 2148008000,
#      'physicalButtons': 64,
#      'physicalLTrigger': 1,
#      'physicalRTrigger': 0,
#      'percent': 63.839996337890625},
#     'post': {'frame': 1020,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 182,
#      'positionX': -80.27328491210938,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'percent': 63.839996337890625,
#      'shieldSize': 59.44000244140625,
#      'lastAttackLanded': 17,
#      'currentComboCount': 4,
#      'lastHitBy': 3,
#      'stocksRemaining': 4,
#      'actionStateCounter': -1,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 1020,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 1781172938,
#      'actionStateId': 66,
#      'positionX': -55.889530181884766,
#      'positionY': 15.702099800109863,
#      'facingDirection': -1,
#      'joystickX': -0.9750000238418579,
#      'joystickY': 0,
#      'cStickX': -0.699999988079071,
#      'cStickY': 0.699999988079071,
#      'trigger': 0.3499999940395355,
#      'buttons': 2151940368,
#      'physicalButtons': 16,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 19.189998626708984},
#     'post': {'frame': 1020,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 66,
#      'positionX': -57.205780029296875,
#      'positionY': 16.90410041809082,
#      'facingDirection': -1,
#      'percent': 19.189998626708984,
#      'shieldSize': 60,
#      'lastAttackLanded': 14,
#      'currentComboCount': 0,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 5,
#      'lCancelStatus': 0}}],
#   'frame': 1020},
#  '1080': {'players': [{'pre': {'frame': 1080,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 457631335,
#      'actionStateId': 70,
#      'positionX': -23.103118896484375,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': 0,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 1,
#      'buttons': 2147483648,
#      'physicalButtons': 0,
#      'physicalLTrigger': 1,
#      'physicalRTrigger': 0,
#      'percent': 63.839996337890625},
#     'post': {'frame': 1080,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 70,
#      'positionX': -22.2031192779541,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'percent': 63.839996337890625,
#      'shieldSize': 57.34001159667969,
#      'lastAttackLanded': 17,
#      'currentComboCount': 4,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 25.799999237060547,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 1080,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 457631335,
#      'actionStateId': 179,
#      'positionX': -42.769134521484375,
#      'positionY': 25.000099182128906,
#      'facingDirection': -1,
#      'joystickX': 0.987500011920929,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 1,
#      'buttons': 2148007936,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 1,
#      'percent': 19.189998626708984},
#     'post': {'frame': 1080,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 179,
#      'positionX': -42.769134521484375,
#      'positionY': 25.000099182128906,
#      'facingDirection': -1,
#      'percent': 19.189998626708984,
#      'shieldSize': 53.84002685546875,
#      'lastAttackLanded': 14,
#      'currentComboCount': 0,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': -1,
#      'lCancelStatus': 0}}],
#   'frame': 1080},
#  '1140': {'players': [{'pre': {'frame': 1140,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 1583430477,
#      'actionStateId': 345,
#      'positionX': 23.94866180419922,
#      'positionY': -0.1799006462097168,
#      'facingDirection': -1,
#      'joystickX': 0,
#      'joystickY': -0.9624999761581421,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 131584,
#      'physicalButtons': 512,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 63.839996337890625},
#     'post': {'frame': 1140,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 345,
#      'positionX': 25.14166259765625,
#      'positionY': -3.5799007415771484,
#      'facingDirection': -1,
#      'percent': 63.839996337890625,
#      'shieldSize': 60,
#      'lastAttackLanded': 17,
#      'currentComboCount': 4,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 5,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 1140,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 1583430477,
#      'actionStateId': 67,
#      'positionX': -28.45053482055664,
#      'positionY': 2.7660999298095703,
#      'facingDirection': -1,
#      'joystickX': 0.987500011920929,
#      'joystickY': 0,
#      'cStickX': 1,
#      'cStickY': 0,
#      'trigger': 0.3499999940395355,
#      'buttons': 2156396816,
#      'physicalButtons': 16,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 19.189998626708984},
#     'post': {'frame': 1140,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 67,
#      'positionX': -27.11741065979004,
#      'positionY': 3.5600998401641846,
#      'facingDirection': -1,
#      'percent': 19.189998626708984,
#      'shieldSize': 57.42144012451172,
#      'lastAttackLanded': 14,
#      'currentComboCount': 0,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 4,
#      'lCancelStatus': 0}}],
#   'frame': 1140},
#  '1200': {'players': [{'pre': {'frame': 1200,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 3917066237,
#      'actionStateId': 20,
#      'positionX': -42.37323760986328,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': -1,
#      'joystickX': -0.987500011920929,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 262144,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 63.839996337890625},
#     'post': {'frame': 1200,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 20,
#      'positionX': -44.545738220214844,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': -1,
#      'percent': 63.839996337890625,
#      'shieldSize': 60,
#      'lastAttackLanded': 18,
#      'currentComboCount': 1,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 4,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 1200,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 3917066237,
#      'actionStateId': 66,
#      'positionX': -5.105288982391357,
#      'positionY': 16.896099090576172,
#      'facingDirection': -1,
#      'joystickX': 0.987500011920929,
#      'joystickY': 0,
#      'cStickX': -0.75,
#      'cStickY': 0.637499988079071,
#      'trigger': 0.3499999940395355,
#      'buttons': 2152202512,
#      'physicalButtons': 16,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 24.919998168945312},
#     'post': {'frame': 1200,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 66,
#      'positionX': -5.556289196014404,
#      'positionY': 17.408098220825195,
#      'facingDirection': -1,
#      'percent': 24.919998168945312,
#      'shieldSize': 59.17143249511719,
#      'lastAttackLanded': 14,
#      'currentComboCount': 0,
#      'lastHitBy': 0,
#      'stocksRemaining': 4,
#      'actionStateCounter': 17,
#      'lCancelStatus': 0}}],
#   'frame': 1200},
#  '1260': {'players': [{'pre': {'frame': 1260,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 1896887580,
#      'actionStateId': 179,
#      'positionX': -1.6477655172348022,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': 0,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 1,
#      'buttons': 2147483712,
#      'physicalButtons': 64,
#      'physicalLTrigger': 1,
#      'physicalRTrigger': 0,
#      'percent': 63.839996337890625},
#     'post': {'frame': 1260,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 179,
#      'positionX': -1.3152655363082886,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'percent': 63.839996337890625,
#      'shieldSize': 54.96002197265625,
#      'lastAttackLanded': 18,
#      'currentComboCount': 1,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': -1,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 1260,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 1896887580,
#      'actionStateId': 26,
#      'positionX': 39.5595817565918,
#      'positionY': 18.4960994720459,
#      'facingDirection': 1,
#      'joystickX': -0.3125,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 0,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 24.919998168945312},
#     'post': {'frame': 1260,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 26,
#      'positionX': 40.47458267211914,
#      'positionY': 19.008098602294922,
#      'facingDirection': 1,
#      'percent': 24.919998168945312,
#      'shieldSize': 60,
#      'lastAttackLanded': 14,
#      'currentComboCount': 0,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 17,
#      'lCancelStatus': 0}}],
#   'frame': 1260},
#  '1320': {'players': [{'pre': {'frame': 1320,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 2335894034,
#      'actionStateId': 345,
#      'positionX': -42.55463790893555,
#      'positionY': 10.45009994506836,
#      'facingDirection': 1,
#      'joystickX': 0,
#      'joystickY': -0.987500011920929,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 131584,
#      'physicalButtons': 512,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 63.839996337890625},
#     'post': {'frame': 1320,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 345,
#      'positionX': -42.55463790893555,
#      'positionY': 7.050099849700928,
#      'facingDirection': 1,
#      'percent': 63.839996337890625,
#      'shieldSize': 57.760009765625,
#      'lastAttackLanded': 18,
#      'currentComboCount': 1,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 3,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 1320,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 2335894034,
#      'actionStateId': 26,
#      'positionX': 11.325578689575195,
#      'positionY': 18.4960994720459,
#      'facingDirection': 1,
#      'joystickX': -0.987500011920929,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 262144,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 27.409997940063477},
#     'post': {'frame': 1320,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 26,
#      'positionX': 9.992453575134277,
#      'positionY': 19.008098602294922,
#      'facingDirection': 1,
#      'percent': 27.409997940063477,
#      'shieldSize': 60,
#      'lastAttackLanded': 14,
#      'currentComboCount': 0,
#      'lastHitBy': 0,
#      'stocksRemaining': 4,
#      'actionStateCounter': 17,
#      'lCancelStatus': 0}}],
#   'frame': 1320},
#  '1380': {'players': [{'pre': {'frame': 1380,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 3983258703,
#      'actionStateId': 179,
#      'positionX': -15.857763290405273,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': 0.987500011920929,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 1,
#      'buttons': 2148010048,
#      'physicalButtons': 2112,
#      'physicalLTrigger': 1,
#      'physicalRTrigger': 0,
#      'percent': 63.839996337890625},
#     'post': {'frame': 1380,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 24,
#      'positionX': -15.445262908935547,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'percent': 63.839996337890625,
#      'shieldSize': 55.240020751953125,
#      'lastAttackLanded': 18,
#      'currentComboCount': 1,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': 0,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 1380,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 3983258703,
#      'actionStateId': 67,
#      'positionX': 20.27832794189453,
#      'positionY': 8.840097427368164,
#      'facingDirection': 1,
#      'joystickX': -0.4124999940395355,
#      'joystickY': 0.42500001192092896,
#      'cStickX': -0.987500011920929,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 4259840,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0.0071428571827709675,
#      'percent': 27.409997940063477},
#     'post': {'frame': 1380,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 67,
#      'positionX': 21.165578842163086,
#      'positionY': 8.61009693145752,
#      'facingDirection': 1,
#      'percent': 27.409997940063477,
#      'shieldSize': 60,
#      'lastAttackLanded': 14,
#      'currentComboCount': 0,
#      'lastHitBy': 0,
#      'stocksRemaining': 4,
#      'actionStateCounter': 4,
#      'lCancelStatus': 0}}],
#   'frame': 1380},
#  '1440': {'players': [{'pre': {'frame': 1440,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 946732746,
#      'actionStateId': 178,
#      'positionX': 31.16204261779785,
#      'positionY': 25.000099182128906,
#      'facingDirection': 1,
#      'joystickX': -0.925000011920929,
#      'joystickY': 0.3499999940395355,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 1,
#      'buttons': 2147745856,
#      'physicalButtons': 64,
#      'physicalLTrigger': 1,
#      'physicalRTrigger': 0,
#      'percent': 63.839996337890625},
#     'post': {'frame': 1440,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 178,
#      'positionX': 31.16204261779785,
#      'positionY': 25.000099182128906,
#      'facingDirection': 1,
#      'percent': 63.839996337890625,
#      'shieldSize': 57.69001007080078,
#      'lastAttackLanded': 18,
#      'currentComboCount': 1,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': -1,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 1440,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 946732746,
#      'actionStateId': 178,
#      'positionX': 52.1524772644043,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': 0.762499988079071,
#      'joystickY': -0.625,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 1,
#      'buttons': 2148007968,
#      'physicalButtons': 32,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 1,
#      'percent': 27.409997940063477},
#     'post': {'frame': 1440,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 178,
#      'positionX': 52.1524772644043,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'percent': 27.409997940063477,
#      'shieldSize': 58.32000732421875,
#      'lastAttackLanded': 14,
#      'currentComboCount': 0,
#      'lastHitBy': 6,
#      'stocksRemaining': 4,
#      'actionStateCounter': -1,
#      'lCancelStatus': 0}}],
#   'frame': 1440},
#  '1500': {'players': [{'pre': {'frame': 1500,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 510139673,
#      'actionStateId': 199,
#      'positionX': -44.40706253051758,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': 0,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 1,
#      'buttons': 2147483712,
#      'physicalButtons': 64,
#      'physicalLTrigger': 1,
#      'physicalRTrigger': 0,
#      'percent': 75.83999633789062},
#     'post': {'frame': 1500,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 199,
#      'positionX': -46.15138626098633,
#      'positionY': 9.999999747378752e-05,
# ...
#  '13080': {'players': [{'pre': {'frame': 13080,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 364879117,
#      'actionStateId': 20,
#      'positionX': -68.53453063964844,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': 0.9750000238418579,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 524288,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 60.13999938964844},
#     'post': {'frame': 13080,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 20,
#      'positionX': -66.92015838623047,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'percent': 60.13999938964844,
#      'shieldSize': 60,
#      'lastAttackLanded': 17,
#      'currentComboCount': 2,
#      'lastHitBy': 3,
#      'stocksRemaining': 1,
#      'actionStateCounter': 2,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 13080,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 364879117,
#      'actionStateId': 343,
#      'positionX': -115.8779067993164,
#      'positionY': -7.331908226013184,
#      'facingDirection': 1,
#      'joystickX': 0.7875000238418579,
#      'joystickY': 0.6000000238418579,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 524288,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0.02142857201397419,
#      'physicalRTrigger': 0,
#      'percent': 4.509999752044678},
#     'post': {'frame': 13080,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 343,
#      'positionX': -115.69630432128906,
#      'positionY': -6.437908172607422,
#      'facingDirection': 1,
#      'percent': 4.509999752044678,
#      'shieldSize': 60,
#      'lastAttackLanded': 14,
#      'currentComboCount': 1,
#      'lastHitBy': 6,
#      'stocksRemaining': 2,
#      'actionStateCounter': 8,
#      'lCancelStatus': 0}}],
#   'frame': 13080},
#  '13140': {'players': [{'pre': {'frame': 13140,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 96729728,
#      'actionStateId': 69,
#      'positionX': -29.761369705200195,
#      'positionY': 9.150099754333496,
#      'facingDirection': 1,
#      'joystickX': 0,
#      'joystickY': -0.987500011920929,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 131328,
#      'physicalButtons': 256,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0.0357142873108387,
#      'percent': 60.13999938964844},
#     'post': {'frame': 13140,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 69,
#      'positionX': -29.531620025634766,
#      'positionY': 9.870100021362305,
#      'facingDirection': 1,
#      'percent': 60.13999938964844,
#      'shieldSize': 60,
#      'lastAttackLanded': 17,
#      'currentComboCount': 2,
#      'lastHitBy': 6,
#      'stocksRemaining': 1,
#      'actionStateCounter': 2,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 13140,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 96729728,
#      'actionStateId': 43,
#      'positionX': -65.75127410888672,
#      'positionY': 0.00010001659393310547,
#      'facingDirection': 1,
#      'joystickX': 0.7250000238418579,
#      'joystickY': -0.675000011920929,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 1,
#      'buttons': 2148007968,
#      'physicalButtons': 32,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 1,
#      'percent': 4.509999752044678},
#     'post': {'frame': 13140,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 43,
#      'positionX': -64.95252227783203,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'percent': 4.509999752044678,
#      'shieldSize': 60,
#      'lastAttackLanded': 14,
#      'currentComboCount': 1,
#      'lastHitBy': 6,
#      'stocksRemaining': 2,
#      'actionStateCounter': 3.009999990463257,
#      'lCancelStatus': 0}}],
#   'frame': 13140},
#  '13200': {'players': [{'pre': {'frame': 13200,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 1896804936,
#      'actionStateId': 178,
#      'positionX': -75.20637512207031,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': -1,
#      'joystickX': 0.9375,
#      'joystickY': 0.3125,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 1,
#      'buttons': 2148008000,
#      'physicalButtons': 64,
#      'physicalLTrigger': 1,
#      'physicalRTrigger': 0,
#      'percent': 60.13999938964844},
#     'post': {'frame': 13200,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 178,
#      'positionX': -75.57612609863281,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': -1,
#      'percent': 60.13999938964844,
#      'shieldSize': 58.8800048828125,
#      'lastAttackLanded': 17,
#      'currentComboCount': 2,
#      'lastHitBy': 6,
#      'stocksRemaining': 1,
#      'actionStateCounter': -1,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 13200,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 1896804936,
#      'actionStateId': 26,
#      'positionX': -85.87145233154297,
#      'positionY': 20.416099548339844,
#      'facingDirection': 1,
#      'joystickX': 0.987500011920929,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': -0.9750000238418579,
#      'trigger': 0,
#      'buttons': 2621440,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 4.509999752044678},
#     'post': {'frame': 13200,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 69,
#      'positionX': -84.538330078125,
#      'positionY': 20.60809898376465,
#      'facingDirection': 1,
#      'percent': 4.509999752044678,
#      'shieldSize': 60,
#      'lastAttackLanded': 14,
#      'currentComboCount': 1,
#      'lastHitBy': 6,
#      'stocksRemaining': 2,
#      'actionStateCounter': 1,
#      'lCancelStatus': 0}}],
#   'frame': 13200},
#  '13260': {'players': [{'pre': {'frame': 13260,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 1656377600,
#      'actionStateId': 90,
#      'positionX': -52.284751892089844,
#      'positionY': 23.513999938964844,
#      'facingDirection': 1,
#      'joystickX': 0.637499988079071,
#      'joystickY': -0.762499988079071,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 1,
#      'buttons': 2147614784,
#      'physicalButtons': 64,
#      'physicalLTrigger': 1,
#      'physicalRTrigger': 0,
#      'percent': 69.13999938964844},
#     'post': {'frame': 13260,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 90,
#      'positionX': -50.80654525756836,
#      'positionY': 25.55632209777832,
#      'facingDirection': 1,
#      'percent': 69.13999938964844,
#      'shieldSize': 48.730018615722656,
#      'lastAttackLanded': 17,
#      'currentComboCount': 2,
#      'lastHitBy': 3,
#      'stocksRemaining': 1,
#      'actionStateCounter': 7,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 13260,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 1656377600,
#      'actionStateId': 56,
#      'positionX': -59.289573669433594,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': 0,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 0,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0.014285714365541935,
#      'physicalRTrigger': 0,
#      'percent': 4.509999752044678},
#     'post': {'frame': 13260,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 56,
#      'positionX': -59.289573669433594,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'percent': 4.509999752044678,
#      'shieldSize': 60,
#      'lastAttackLanded': 8,
#      'currentComboCount': 1,
#      'lastHitBy': 6,
#      'stocksRemaining': 2,
#      'actionStateCounter': 15,
#      'lCancelStatus': 0}}],
#   'frame': 13260},
#  '13320': {'players': [{'pre': {'frame': 13320,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 1349054297,
#      'actionStateId': 88,
#      'positionX': 32.59465789794922,
#      'positionY': 10.327991485595703,
#      'facingDirection': -1,
#      'joystickX': 0.949999988079071,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 524288,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 79.45999908447266},
#     'post': {'frame': 13320,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 88,
#      'positionX': 35.12017059326172,
#      'positionY': 8.979415893554688,
#      'facingDirection': -1,
#      'percent': 79.45999908447266,
#      'shieldSize': 52.93000030517578,
#      'lastAttackLanded': 17,
#      'currentComboCount': 2,
#      'lastHitBy': 3,
#      'stocksRemaining': 1,
#      'actionStateCounter': 13,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 13320,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 1349054297,
#      'actionStateId': 71,
#      'positionX': -8.745323181152344,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'joystickX': 0.987500011920929,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 524288,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0.014285714365541935,
#      'physicalRTrigger': 0,
#      'percent': 4.509999752044678},
#     'post': {'frame': 13320,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 71,
#      'positionX': -7.77219820022583,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': 1,
#      'percent': 4.509999752044678,
#      'shieldSize': 60,
#      'lastAttackLanded': 14,
#      'currentComboCount': 0,
#      'lastHitBy': 6,
#      'stocksRemaining': 2,
#      'actionStateCounter': 6.019999980926514,
#      'lCancelStatus': 0}}],
#   'frame': 13320},
#  '13380': {'players': [{'pre': {'frame': 13380,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 3427027573,
#      'actionStateId': 18,
#      'positionX': 70.85336303710938,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': -1,
#      'joystickX': -0.987500011920929,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 262144,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 79.45999908447266},
#     'post': {'frame': 13380,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 20,
#      'positionX': 71.26976776123047,
#      'positionY': 9.999999747378752e-05,
#      'facingDirection': -1,
#      'percent': 79.45999908447266,
#      'shieldSize': 57.129981994628906,
#      'lastAttackLanded': 17,
#      'currentComboCount': 2,
#      'lastHitBy': 3,
#      'stocksRemaining': 1,
#      'actionStateCounter': 1,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 13380,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 3427027573,
#      'actionStateId': 26,
#      'positionX': 17.642061233520508,
#      'positionY': 19.840099334716797,
#      'facingDirection': -1,
#      'joystickX': -0.9375,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 262144,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 4.509999752044678},
#     'post': {'frame': 13380,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 26,
#      'positionX': 16.358936309814453,
#      'positionY': 20.160099029541016,
#      'facingDirection': -1,
#      'percent': 4.509999752044678,
#      'shieldSize': 60,
#      'lastAttackLanded': 14,
#      'currentComboCount': 0,
#      'lastHitBy': 6,
#      'stocksRemaining': 2,
#      'actionStateCounter': 20,
#      'lCancelStatus': 0}}],
#   'frame': 13380},
#  '13440': {'players': [{'pre': {'frame': 13440,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 1092838636,
#      'actionStateId': 90,
#      'positionX': 0.547641396522522,
#      'positionY': 42.00324630737305,
#      'facingDirection': 1,
#      'joystickX': -0.987500011920929,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 262144,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 87.73999786376953},
#     'post': {'frame': 13440,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 90,
#      'positionX': -0.10991853475570679,
#      'positionY': 42.475868225097656,
#      'facingDirection': 1,
#      'percent': 87.73999786376953,
#      'shieldSize': 56.009986877441406,
#      'lastAttackLanded': 17,
#      'currentComboCount': 2,
#      'lastHitBy': 3,
#      'stocksRemaining': 1,
#      'actionStateCounter': 26,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 13440,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 1092838636,
#      'actionStateId': 25,
#      'positionX': 23.55606460571289,
#      'positionY': 4.608099937438965,
#      'facingDirection': -1,
#      'joystickX': -0.987500011920929,
#      'joystickY': 0,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 262144,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0.0071428571827709675,
#      'percent': 4.509999752044678},
#     'post': {'frame': 13440,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 25,
#      'positionX': 22.22294044494629,
#      'positionY': 6.01609992980957,
#      'facingDirection': -1,
#      'percent': 4.509999752044678,
#      'shieldSize': 60,
#      'lastAttackLanded': 8,
#      'currentComboCount': 1,
#      'lastHitBy': 6,
#      'stocksRemaining': 2,
#      'actionStateCounter': 3,
#      'lCancelStatus': 0}}],
#   'frame': 13440},
#  '13500': {'players': [{'pre': {'frame': 13500,
#      'playerIndex': 0,
#      'isFollower': False,
#      'seed': 2973222842,
#      'actionStateId': 89,
#      'positionX': -215.11178588867188,
#      'positionY': 97.69908142089844,
#      'facingDirection': 1,
#      'joystickX': -0.7875000238418579,
#      'joystickY': -0.612500011920929,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 262144,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 115.73999786376953},
#     'post': {'frame': 13500,
#      'playerIndex': 0,
#      'isFollower': False,
#      'internalCharacterId': 1,
#      'actionStateId': 89,
#      'positionX': -225.77474975585938,
#      'positionY': 100.41679382324219,
#      'facingDirection': 1,
#      'percent': 115.73999786376953,
#      'shieldSize': 60,
#      'lastAttackLanded': 17,
#      'currentComboCount': 2,
#      'lastHitBy': 3,
#      'stocksRemaining': 1,
#      'actionStateCounter': 19,
#      'lCancelStatus': 0}},
#    None,
#    None,
#    {'pre': {'frame': 13500,
#      'playerIndex': 3,
#      'isFollower': False,
#      'seed': 2973222842,
#      'actionStateId': 370,
#      'positionX': -16.027332305908203,
#      'positionY': 40.61809158325195,
#      'facingDirection': -1,
#      'joystickX': 0.637499988079071,
#      'joystickY': -0.5375000238418579,
#      'cStickX': 0,
#      'cStickY': 0,
#      'trigger': 0,
#      'buttons': 524288,
#      'physicalButtons': 0,
#      'physicalLTrigger': 0,
#      'physicalRTrigger': 0,
#      'percent': 4.509999752044678},
#     'post': {'frame': 13500,
#      'playerIndex': 3,
#      'isFollower': False,
#      'internalCharacterId': 15,
#      'actionStateId': 370,
#      'positionX': -16.027332305908203,
#      'positionY': 40.34809112548828,
#      'facingDirection': -1,
#      'percent': 4.509999752044678,
#      'shieldSize': 60,
#      'lastAttackLanded': 21,
#      'currentComboCount': 0,
#      'lastHitBy': 6,
#      'stocksRemaining': 2,
#      'actionStateCounter': 19,
#      'lCancelStatus': 0}}],
#   'frame': 13500}}

# %%
setting_features = ['stageId']
game_features = {
    'pre': [], 
    'post': ['positionX', 'positionY', 'facingDirection', 
             'percent', 'shieldSize', 'stocksRemaining', 'lCancelStatus']
}
jig_id = settings['jig_id']
other_id = settings['other_id']
setting_data = [settings[feat] for feat in setting_features]

# %%
data = []
for frame in game:
    frame_data = []
    frame_data += [int(frame)]
    for k in game_features:
        frame_data += [game[frame]['players'][jig_id][k][feat] for feat in game_features[k]]
    for k in game_features:
        frame_data += [game[frame]['players'][other_id][k][feat] for feat in game_features[k]]
    frame_data += setting_data
    
    data.append(frame_data)

columns = ['frame']
for k in game_features:
    columns += ["p1_{}_{}".format(k, feat) for feat in game_features[k]]
for k in game_features:
    columns += ["p2_{}_{}".format(k, feat) for feat in game_features[k]]
columns += setting_features

# %%
pd.DataFrame(data, columns=columns).to_csv("test_game.csv", index=False)
